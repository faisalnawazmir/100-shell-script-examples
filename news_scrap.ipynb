# %% [markdown]
# <a href="https://colab.research.google.com/github/faisalnawazmir/100-shell-script-examples/blob/master/news_scrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests beautifulsoup4 newspaper3k scrapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 26.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 6.5 MB/s eta 0:00:00
# ...

# %%
url = 'https://www.bbc.com/news'

# %%
from newspaper import Article

url = 'https://www.bbc.com/news'
article = Article(url)
article.download()
article.parse()
print(f"Title: {article.title}")
print(f"Text: {article.text}")
# Out:
# Title: BBC News
# Text: Kick It Out questions Fifa over Fernandez video
#
# Kick It Out (KIO) asks Fifa if it has taken any action over a video posted on social media by Chelsea's Enzo Fernandez last year featuring an alleged "racist and transphobic" chant.

# %%
print(f"Title: {article.title}")
print(f"Authors: {article.authors}")
print(f"Publication Date: {article.publish_date}")
print(f"Text: {article.text}")
print(f"Top Image: {article.top_image}")
print(f"Videos: {article.movies}")
# Out:
# Title: BBC News
# Authors: []
# Publication Date: None
# Text: Kick It Out questions Fifa over Fernandez video
#
# Kick It Out (KIO) asks Fifa if it has taken any action over a video posted on social media by Chelsea's Enzo Fernandez last year featuring an alleged "racist and transphobic" chant.
# Top Image: https://www.bbc.com/bbcx/apple-touch-icon.png
# Videos: []

# %%
pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Perform NLP on the article
article.nlp()

print(f"Keywords: {article.keywords}")
print(f"Summary: {article.summary}")
# Out:
# Keywords: ['questions', 'fernandez', 'social', 'posted', 'racist', 'taken', 'video', 'transphobic', 'videokick', 'bbc', 'fifa']
# Summary: Kick It Out questions Fifa over Fernandez videoKick It Out (KIO) asks Fifa if it has taken any action over a video posted on social media by Chelsea's Enzo Fernandez last year featuring an alleged "racist and transphobic" chant.

# %%
import newspaper

# Build a news source
cnn_paper = newspaper.build('http://cnn.com')

# Iterate through the articles
for article in cnn_paper.articles:
    print(article.url)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: OK for url: https://edition.cnn.com/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: OK for url: https://edition.cnn.com/feeds
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: OK for url: https://edition.cnn.com/feed
# https://edition.cnn.com/business/media
# https://edition.cnn.com/travel/news
# https://edition.cnn.com/audio/podcasts/all-there-is-with-anderson-cooper
# http://cnn.com/2025/01/16/politics/biden-poignant-farewell-analysis/index.html
# http://cnn.com/2025/01/15/entertainment/neil-gaiman-sexual-abuse-allegations-intl-scli/index.html
# http://cnn.com/2025/01/15/us/whats-in-the-hamas-israel-ceasefire-and-hostage-release-deal/index.html
# http://cnn.com/2025/01/15/tech/trump-tiktok-ban/index.html
# http://cnn.com/science/live-news/blue-origin-new-glenn-rocket-launch-01-16-25/index.html
# http://cnn.com/weather/live-news/fires-los-angeles-california-01-16-25/index.html
# ...

# %%
cnn_paper = newspaper.build('http://cnn.com', memoize_articles=False)
